# %%
import pandas as pd
from sklearn.tree import DecisionTreeClassifier
import numpy as np

# %%
#loading encoded data from csv

train_encoded = pd.read_csv("data/BinaryClassify/train_nsl_kdd_binary_encoded.csv")
test_encoded = pd.read_csv("data/BinaryClassify/train_nsl_kdd_binary_encoded.csv")

# %%
X = train_encoded.drop('binaryoutcome', axis=1)
Y = train_encoded[['binaryoutcome']]

# %%
# Use Decision Tree to calculate Gain Ratio
dt = DecisionTreeClassifier()
dt.fit(X, Y)
# Out:
# DecisionTreeClassifier()

# %%
# Access feature importances (which can be considered as Gain Ratio)
gain_ratio_values = dt.feature_importances_

# %%
# Get the indices of top k features
k = 42  # Change this value as needed
top_k_indices = (-gain_ratio_values).argsort()[:k]

# %%
# Get the selected features and corresponding Gain Ratio values
selected_features_gain_ratio = X.columns[top_k_indices]

# %%
# Display the selected features and Gain Ratio values
print("Selected Features and Gini Index Values:")
for feature, gain_ratio_value in zip(selected_features_gain_ratio, gain_ratio_values[top_k_indices]):
    print(f"{feature}: {gain_ratio_value}")
# Out:
# Selected Features and Gini Index Values:
# src_bytes: 0.7427285001252075
# protocol_type: 0.06625606479324347
# level: 0.05973386724420968
# dst_host_srv_count: 0.04545824796524355
# dst_host_srv_rerror_rate: 0.024778027076462605
# dst_bytes: 0.01973124862898601
# dst_host_same_srv_rate: 0.011030009006958103
# logged_in: 0.009891343521921506
# dst_host_srv_serror_rate: 0.004625109852207983
# service: 0.0035446051274975548
# dst_host_srv_diff_host_rate: 0.0014983941813477232
# dst_host_diff_srv_rate: 0.001436203385139328
# hot: 0.001221292405632614
# dst_host_serror_rate: 0.0011090423214083717
# dst_host_rerror_rate: 0.0009828352435547836
# count: 0.0009254808712137124
# duration: 0.0008870881284916413
# flag: 0.0007670690385967691
# serror_rate: 0.0007601409952988305
# dst_host_same_src_port_rate: 0.0007362911360886623
# srv_count: 0.0007097736696675576
# dst_host_count: 0.0006128084397405927
# srv_serror_rate: 0.0001323178184581096
# srv_diff_host_rate: 8.274755456863063e-05
# num_failed_logins: 7.07908958281436e-05
# same_srv_rate: 5.379187120242654e-05
# num_compromised: 5.237689255175267e-05
# diff_srv_rate: 4.998557854710395e-05
# srv_rerror_rate: 3.4972669235288236e-05
# rerror_rate: 3.186435982235949e-05
# num_shells: 3.048589849406809e-05
# num_file_creations: 2.1270458956214445e-05
# num_root: 1.5952844217160834e-05
# su_attempted: 0.0
# root_shell: 0.0
# is_guest_login: 0.0
# num_outbound_cmds: 0.0
# urgent: 0.0
# wrong_fragment: 0.0
# land: 0.0
# num_access_files: 0.0
# is_host_login: 0.0

# %%
sorted_chi2 = pd.DataFrame(np.array([list(selected_features_gain_ratio),list(gain_ratio_values)]).T,columns=['feature','gainratio'])

# %%
sorted_chi2=sorted_chi2.sort_values(by='gainratio',ascending=False)

# %%
#  sorted_chi2.to_csv('gainratio/sorted_gr.csv',index=False)
