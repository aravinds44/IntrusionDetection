# %%
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import chi2
import pandas as pd

# %%
#loading encoded data from csv

train_encoded = pd.read_csv("data/BinaryClassify/train_nsl_kdd_binary_encoded.csv")
test_encoded = pd.read_csv("data/BinaryClassify/train_nsl_kdd_binary_encoded.csv")

# %%
train_encoded.head()
# Out:
#    duration  protocol_type  service  flag  src_bytes  dst_bytes  land  \
# 0         0              2       44     9        146          0     0
# 1         0              1       49     5          0          0     0
# 2         0              1       24     9        232       8153     0
# 3         0              1       24     9        199        420     0
# 4         0              1       49     1          0          0     0
#
#    wrong_fragment  urgent  hot  ...  dst_host_same_srv_rate  \
# 0               0       0    0  ...                    0.00
# 1               0       0    0  ...                    0.10
# 2               0       0    0  ...                    1.00
# 3               0       0    0  ...                    1.00
# 4               0       0    0  ...                    0.07
#
#    dst_host_diff_srv_rate  dst_host_same_src_port_rate  \
# 0                    0.60                         0.88
# 1                    0.05                         0.00
# 2                    0.00                         0.03
# 3                    0.00                         0.00
# 4                    0.07                         0.00
#
#    dst_host_srv_diff_host_rate  dst_host_serror_rate  \
# 0                         0.00                  0.00
# 1                         0.00                  1.00
# 2                         0.04                  0.03
# 3                         0.00                  0.00
# 4                         0.00                  0.00
#
#    dst_host_srv_serror_rate  dst_host_rerror_rate  dst_host_srv_rerror_rate  \
# 0                      0.00                   0.0                      0.00
# 1                      1.00                   0.0                      0.00
# 2                      0.01                   0.0                      0.01
# 3                      0.00                   0.0                      0.00
# 4                      0.00                   1.0                      1.00
#
#    level  binaryoutcome
# 0     15              1
# 1     19              0
# 2     21              1
# 3     21              1
# 4     21              0
#
# [5 rows x 43 columns]

# %%
test_encoded.head()
# Out:
#    duration  protocol_type  service  flag  src_bytes  dst_bytes  land  \
# 0         0              2       44     9        146          0     0
# 1         0              1       49     5          0          0     0
# 2         0              1       24     9        232       8153     0
# 3         0              1       24     9        199        420     0
# 4         0              1       49     1          0          0     0
#
#    wrong_fragment  urgent  hot  ...  dst_host_same_srv_rate  \
# 0               0       0    0  ...                    0.00
# 1               0       0    0  ...                    0.10
# 2               0       0    0  ...                    1.00
# 3               0       0    0  ...                    1.00
# 4               0       0    0  ...                    0.07
#
#    dst_host_diff_srv_rate  dst_host_same_src_port_rate  \
# 0                    0.60                         0.88
# 1                    0.05                         0.00
# 2                    0.00                         0.03
# 3                    0.00                         0.00
# 4                    0.07                         0.00
#
#    dst_host_srv_diff_host_rate  dst_host_serror_rate  \
# 0                         0.00                  0.00
# 1                         0.00                  1.00
# 2                         0.04                  0.03
# 3                         0.00                  0.00
# 4                         0.00                  0.00
#
#    dst_host_srv_serror_rate  dst_host_rerror_rate  dst_host_srv_rerror_rate  \
# 0                      0.00                   0.0                      0.00
# 1                      1.00                   0.0                      0.00
# 2                      0.01                   0.0                      0.01
# 3                      0.00                   0.0                      0.00
# 4                      0.00                   1.0                      1.00
#
#    level  binaryoutcome
# 0     15              1
# 1     19              0
# 2     21              1
# 3     21              1
# 4     21              0
#
# [5 rows x 43 columns]

# %%
xtrain = train_encoded.drop('binaryoutcome', axis=1)
ytrain = train_encoded[['binaryoutcome']]
xtest = test_encoded.drop('binaryoutcome', axis=1)
ytest = test_encoded[['binaryoutcome']]

# %%
# Feature selection using Chi-square
chi2_selector = SelectKBest(chi2, k=42)  # Select top 10 features (you can change this value)
X_chi2 = chi2_selector.fit_transform(xtrain,ytrain)

# %%
# Get the selected features
selected_features = xtrain.columns[chi2_selector.get_support()]
chi2_values = chi2_selector.scores_

# %%
# Display the selected features and Chi-square values
print("Selected Features and Chi-square Values:")
for feature, chi2_value in zip(selected_features, chi2_values):
    print(f"{feature}: {chi2_value}")
# Out:
# Selected Features and Chi-square Values:
# duration: 7082565.303892097
# service: 1723.289569546626
# flag: 82437.93955815387
# src_bytes: 54653.93292607195
# dst_bytes: 3340257591.4457445
# count: 1746063122.1702244
# srv_serror_rate: 6.512199407543797
# dst_host_count: 3282.6784240150096
# dst_host_srv_count: 1.8171812299380998
# dst_host_srv_serror_rate: 487.6709925760863
